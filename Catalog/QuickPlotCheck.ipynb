# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
spectra = np.load('spectra.npy')
print(spectra.shape)
# Out:
# (420, 471)

# %%
plt.figure()
plt.plot(spectra[419])

# %%
1 - (1300/1420)
# Out:
# 0.08450704225352113

# %%
z = 0.1
frest = 1420
fobs = frest/(1+z)
print(fo
